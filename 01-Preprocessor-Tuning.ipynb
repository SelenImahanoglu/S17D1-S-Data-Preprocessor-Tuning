# %% [markdown]
# # Preprocessor Tuning (Ön İşlemci Ayarlama)

# %% [markdown]
# ## (0) `tumors` Dataset

# %% [markdown]
# * 👩🏻‍⚕️ Aşağıdaki veri seti, <font color=red>malignant</font> veya <font color=green>benign</font> olan tümörleri tanımlar.
# * 🎯 Görev, mümkün olduğunca çok sayıda <font color=red>malignant</font> tümörü tespit etmektir.

# %%
import pandas as pd
import urllib.request
import ssl

# SSL doğrulamasını tamamen kapatan özel bir bağlam yaratıyoruz
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

pd.set_option('display.max_columns', None)

url = "https://d32aokrjazspmn.cloudfront.net/materials/tumors_dataset.csv"

# Veriyi çekerken bu özel bağlamı kullanmasını söylüyoruz
response = urllib.request.urlopen(url, context=ctx)
data = pd.read_csv(response)

data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34             NaN     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  radius error  texture error  perimeter error  \
# ...

# %%
round(data.malignant.value_counts(normalize = True),2)
# Out:
# malignant
# 0    0.63
# 1    0.37
# Name: proportion, dtype: float64

# %% [markdown]
# ## (1) Pipeline Oluşturma

# %% [markdown]
# ❓ **Soru: Bir Pipeline Oluşturma** ❓
#
# Aşağıdaki adımları `pipeline` adlı bir **`Pipeline`** nesnesi içinde birleştirin:
#
# 1. Eksik değerleri **`KNNImputer`** ile doldurun
# 2. Tüm (sayısal) feature’ları **`MinMaxScaler`** ile ölçekleyin
# 3. Varsayılan parametrelerle bir **`LogisticRegression`** modeli kurun

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression

# Bağımsız değişkenleri (X) ve hedef değişkeni (y) ayıralım
X = data.drop(columns=['malignant'])
y = data['malignant']

# 1. Pipeline'ı oluşturuyoruz
# Sırasıyla: Eksik veri doldurma -> Ölçeklendirme -> Model
pipeline = make_pipeline(
    KNNImputer(), 
    MinMaxScaler(), 
    LogisticRegression()
)

# Pipeline nesnesini ekranda görelim
pipeline
# Out:
# Pipeline(steps=[('knnimputer', KNNImputer()), ('minmaxscaler', MinMaxScaler()),
#                 ('logisticregression', LogisticRegression())])

# %% [markdown]
# ## (2) Pipeline modelini optimize etme

# %% [markdown]
# ❓ **Soru (Bir Pipeline üzerinde GridSearch)** ❓
#
# * KNN imputer için **en uygun komşu sayısı** hangisidir: **2, 5 veya 10**?
#     * Pipeline’ınız üzerinde bir **GridSearch** gerçekleştirin ve cevabınızı `n_best` adlı değişkende saklayın.
#     * _Dikkat: Grid Search sırasında görevle **alakalı bir scoring metriği** kullandığınızdan emin olun, sadece söylemiş olalım 🙂_
# * Bu challenge’da bir train/test split kullanmak yerine, **tüm veri seti üzerinde GridSearch** yapmaktan çekinmeyin. Buradaki amaç sadece **Pipeline’lara alışmak** 🙂

# %%
n_best = 5

# %%
from sklearn.model_selection import GridSearchCV

# 1. Pipeline içindeki KNNImputer'ın parametresini arıyoruz.
# Pipeline bileşenlerinin adını küçük harfle yazıp, çift alt çizgi '__' ile parametreye bağlarız
param_grid = {
    'knnimputer__n_neighbors': [2, 5, 10]
}

# 2. GridSearch'ü Recall (Duyarlılık) metriğiyle kuruyoruz
grid_search = GridSearchCV(
    pipeline,
    param_grid=param_grid,
    scoring='recall', # En kritik kısım! Kötü huylu tümörleri kaçırmak istemiyoruz.
    cv=5
)

# 3. Tüm veriyi kullanarak modeli eğitiyor ve en iyi parametreyi arıyoruz
grid_search.fit(X, y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('knnimputer', KNNImputer()),
#                                        ('minmaxscaler', MinMaxScaler()),
#                                        ('logisticregression',
#                                         LogisticRegression())]),
#              param_grid={'knnimputer__n_neighbors': [2, 5, 10]},
#              scoring='recall')

# %%
# Kazanan komşu sayısını ve skorunu ekrana yazdırıyoruz
best_k = grid_search.best_params_['knnimputer__n_neighbors']
best_score = grid_search.best_score_

print(f"🏆 En çok tümörü yakalayan komşu sayısı: {best_k}")
print(f"📈 En İyi Recall Skoru: {best_score:.4f}")
# Out:
# 🏆 En çok tümörü yakalayan komşu sayısı: 5
# 📈 En İyi Recall Skoru: 0.9245

# %% [markdown]
# ## (3)  Pipeline'nın Değerlendirilmesi

# %% [markdown]
# ❓ **Soru: En iyi pipeline’ın performansı nedir?** ❓
#
# - En iyi pipeline’ınızı mutlaka **cross-validation** ile değerlendirdiğinizden emin olun!
# - Sonucu `cv_score` adlı bir değişkende **float** bir sayı olarak saklayın

# %%
cv_score = None

# %%
from sklearn.model_selection import cross_val_score

# 1. GridSearch'ün bulduğu şampiyon pipeline'ı çağırıyoruz
best_pipeline = grid_search.best_estimator_

# 2. 5 katlı çapraz doğrulama ile Recall skorlarını hesaplıyoruz
cv_scores = cross_val_score(best_pipeline, X, y, cv=5, scoring='recall')

# 3. Yukarıda 'None' olan cv_score değişkenini, bulduğumuz ortalamayla eziyoruz
cv_score = cv_scores.mean()

print(f"Şampiyon Pipeline'ın Ortalama Recall Skoru: {cv_score:.4f}")
# Out:
# Şampiyon Pipeline'ın Ortalama Recall Skoru: 0.9245

# %%
from nbresult import ChallengeResult

result = ChallengeResult(
    'solution', 
    n_best = n_best,
    cv_score=cv_score
)

result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.9, pytest-8.3.4, pluggy-1.5.0 -- /Users/macos/.pyenv/versions/3.12.9/envs/workintech/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/macos/Desktop/S17D1-S-Data-Preprocessor-Tuning/tests
# plugins: dash-4.0.0, anyio-4.8.0, typeguard-4.4.2
# collecting ... collected 2 items
#
# test_solution.py::TestSolution::test_n_neighbours PASSED                 [ 50%]
# test_solution.py::TestSolution::test_score_good_enough PASSED            [100%]
#
# ============================== 2 passed in 0.90s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/solution.pickle
#
# git commit -m 'Completed solution step'
#
# git push origin master

# %% [markdown]
# ## (4) Eğitilmiş ve pipeline içine alınmış bir model ile tahmin yapma

# %% [markdown]
# 👇 İşte yeni bir tümör.

# %%
import pandas as pd
import urllib.request
import ssl

# SSL doğrulamasını kapatan özel bağlamı tekrar oluşturuyoruz
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

new_url = "https://d32aokrjazspmn.cloudfront.net/materials/new_tumor.csv"

# Veriyi özel bağlam (context=ctx) ile çekiyoruz
response = urllib.request.urlopen(new_url, context=ctx)
new_data = pd.read_csv(response)

new_data
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        20.57         17.77           132.9     1326.0          0.08474
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.07864          0.0869              0.07017         0.1812
#
#    mean fractal dimension  radius error  texture error  perimeter error  \
# 0                 0.05667        0.5435         0.7339            3.398
#
#    area error  smoothness error  compactness error  concavity error  \
# 0       74.08          0.005225            0.01308           0.0186
#
#    concave points error  symmetry error  fractal dimension error  \
# 0                0.0134         0.01389                 0.003532
#
#    worst radius  worst texture  worst perimeter  worst area  worst smoothness  \
# 0         24.99          23.41            158.8      1956.0            0.1238
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# ...

# %% [markdown]
# ❓ **Soru: En iyi (optimal) pipeline’ınızı kullanarak yeni tümörün malignant olup olmadığını tahmin edin** ❓

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.impute import KNNImputer

# 1. n_best (5) komşu sayısını kullanan yeni bir Pipeline kuralım
pipeline_scaling = make_pipeline(
    KNNImputer(n_neighbors=n_best), 
    MinMaxScaler(), # Bu bir yer tutucu, GridSearch bunu değiştirecek
    LogisticRegression()
)

# 2. Grid dictionary (Sadece scaler adımını değiştireceğiz)
# make_pipeline kullandığımız için adımın adı küçük harflerle 'minmaxscaler' olur
grid = {
    'minmaxscaler': [MinMaxScaler(), StandardScaler(), RobustScaler()]
}

# 3. Grid Search'ü başlatıyoruz (Recall kullanmayı unutmuyoruz!)
search_scaling = GridSearchCV(
    pipeline_scaling,
    param_grid=grid,
    scoring='recall',
    cv=5
)

# Aramayı fit edelim
search_scaling.fit(X, y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('knnimputer', KNNImputer()),
#                                        ('minmaxscaler', MinMaxScaler()),
#                                        ('logisticregression',
#                                         LogisticRegression())]),
#              param_grid={'minmaxscaler': [MinMaxScaler(), StandardScaler(),
#                                           RobustScaler()]},
#              scoring='recall')

# %%
# Kazanan scaler'ı değişkene atayalım
scaler_best = search_scaling.best_params_['minmaxscaler']

print(f"🥇 En İyi Scaler: {scaler_best}")
print(f"📈 Ulaştığı Recall Skoru: {search_scaling.best_score_:.4f}")
# Out:
# 🥇 En İyi Scaler: RobustScaler()
# 📈 Ulaştığı Recall Skoru: 0.9670

# %%
# Şampiyon modelimiz (search_scaling) ile yeni veriyi tahmin ediyoruz
prediction = search_scaling.predict(new_data)

# Sonucu ekrana yazdıralım
if prediction[0] == 1:
    print("🩺 Modelin Tahmini: MALIGNANT (Kötü Huylu) 🚨")
else:
    print("🩺 Modelin Tahmini: BENIGN (İyi Huylu) ✅")
# Out:
# 🩺 Modelin Tahmini: MALIGNANT (Kötü Huylu) 🚨

# %% [markdown]
# 🏁 Tebrikler! Artık pipeline oluşturma konusunda uzmansınız!
#
# 💾 Notebook’unuzu `git add/commit/push` yapmayı unutmayın...
